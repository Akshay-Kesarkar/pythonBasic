# %%
# 1. What does RGBA stand for?

# Ans

# RGBA stands for Red-Green-Blue-Alpha
# The RGB color model is extended in this specification to include “alpha” to allow specification of the opacity of a color.

# %%
 # 2. From the Pillow module, how do you get the RGBA value of any images?
    
#Import required image modules
from PIL import Image,ImageColor

# using ImageColor.getcolor(color ,'RGBA')

img3=ImageColor.getcolor('Red', 'RGBA') 
print(img3)
# Out:
# (255, 0, 0, 255)

# %%
# What is a box tuple, and how does it work?

# Ans

# Importing Image class from PIL module
from PIL import Image
 
# Opens a image in RGB mode
im = Image.open(r"C:\Users\HP\Desktop\Assignment_img\mongodb_upload.png")
# Size of the image in pixels
# (size of original image)
# (This is not mandatory)
width, height = im.size
 
# Setting the points for cropped image
left = 5
top = height / 4
right = 164
bottom = 3 * height / 4
 
# Cropped image of above dimension
# (It will not change original image)
im1 = im.crop((left, top, right, bottom))
 
# Shows the image in image viewer
im1.show()

# The region is defined by a 4-tuple, where coordinates are (left, upper, right, lower). 
#The Python Imaging Library uses a coordinate system with (0, 0) in the upper left corner.

# %%
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

#Ans
# imageObj.size is a tuple of two integers, the width and the height.
pil_im = Image.open(r'C:\Users\HP\Desktop\Output.png')
print(width)
print(height)
display(pil_im)
width, height = pil_im.size
# Out:
# 1364
# 702
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1366x768 at 0x26E04600790>

# %%
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# Ans

pil_im2=pil_im.crop((0,0,100,150))
print(width,"*",height)
display(pil_im2)
width, height = pil_im2.size
# Out:
# 100 * 100
# <PIL.Image.Image image mode=RGB size=100x150 at 0x26E061C4E80>

# %%
# 6. After making changes to an Image object, how could you save it as an image file?

# Ans
# By calling imageObj.save('new_filename.png')

# %%
# 7. What module contains Pillow’s shape-drawing code?

#Ans
# The ImageDraw module contains code to draw on images.

# %%
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# Ans
# ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). 
# They are returned by passing the Image object to the ImageDraw.Draw() function.

# %%
from PIL import Image, ImageDraw
im = Image.new('RGBA', (200, 200), 'white')
draw = ImageDraw.Draw(im)
dr1=draw.line([(0, 0), (199, 0), (199, 199), (0, 199), (0, 0)], fill='black')
dr2=draw.rectangle((20, 30, 60, 60), fill='blue')
dr3=draw.ellipse((120, 30, 160, 60), fill='red')
dr=draw.polygon(((57, 87), (79, 62), (94, 85), (120, 90), (103, 113)),fill='brown')
display(im)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x26E04A6B5B0>
